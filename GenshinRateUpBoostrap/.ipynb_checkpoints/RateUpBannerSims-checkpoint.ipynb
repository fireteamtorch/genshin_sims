# %%
import random
import sys

# %%
draw_nums_from_whales = [77,78,37,67,36,34,46,68,55,82,75,52,78,32,79,2,6,9,78,89,12,58,86,54,62,56,77,76,3,14,80,77,9,44,35,45,38,76,77,70,52,58,78,70,23,47,81,50,67,79,76,77,13,76,78,78,76,78,30,80,62,85,79,79,83,67,42,23,76,76,62,82,81,60,75,54,68,75,5,76,80,71,77,38,78,76,74,80,77,62,42,51,77,77,40,78,42,78,16,19,52,75,80,54,78,79,75,68,51,80,39,76,68,79,79,14,75,47,74,69,3,66,77,74,14,47,78,77,78,1,11,75,7,76,77,80,75,32,70,82,22,77,70,76]

# %%
def SimNumDrawsToFeaturedChar_FromData(data, num_wanted_featured_chars = 1):
    num_draws = 0
    for i in range(num_wanted_featured_chars):
        if random.uniform(0, 1) <= 0.5:
            num_draws += random.sample(data, 1)[0]
        else:
            num_draws += random.sample(data, 1)[0] + random.sample(data, 1)[0]
    return num_draws

# %%
def SampleHistogramForFeaturedCharacterDraws_FromData(data, num_wanted_featured_chars, num_sims = 10000):
    hist_data = [0] * (num_wanted_featured_chars * 180)
for curr_iter in range(0, num_sims):
    results.append(SimNumDrawsToFeaturedChar_FromData(draw_nums_from_whales, num_featured_chars))

# %%
def GenerateCumulativeList(data, max_num = -1):
    
    if max_num < 0:
        max_num = max(data)
        
    curr_index_in_data = 0;
    hist_data = [0] * max_num
    
    for curr_item in data:
        hist_data[curr_item - 1] = hist_data[curr_item - 1] + 1
        
    print(hist_data)

# %%
[0]*1
# Out:
# [0]

# %%
num_sims = 10000
num_featured_chars = 5
results = []
for curr_iter in range(0, num_sims):
    results.append(SimNumDrawsToFeaturedChar_FromData(draw_nums_from_whales, num_featured_chars))

# %%
results.sort()
results
# Out:
# [123,
#  131,
#  131,
#  143,
#  143,
#  145,
#  151,
#  160,
#  160,
#  170,
#  172,
#  177,
#  179,
#  180,
#  182,
#  182,
#  185,
#  187,
#  187,
#  189,
#  189,
#  193,
#  193,
#  194,
#  195,
#  198,
#  198,
#  199,
#  199,
#  199,
#  200,
#  200,
#  200,
#  200,
#  201,
#  201,
#  204,
#  204,
#  205,
#  206,
#  206,
#  206,
#  206,
#  207,
#  207,
#  208,
#  209,
#  210,
#  211,
#  211,
#  212,
#  213,
#  213,
#  215,
#  216,
#  216,
#  216,
#  217,
#  219,
#  219,
#  220,
#  220,
#  223,
#  225,
#  226,
#  227,
#  228,
#  228,
#  228,
#  228,
#  228,
#  229,
#  229,
#  229,
#  229,
#  229,
#  230,
#  230,
#  230,
#  230,
#  231,
#  231,
#  231,
#  232,
#  232,
#  232,
#  232,
#  232,
#  233,
#  233,
#  234,
#  234,
#  234,
#  234,
#  235,
#  235,
#  235,
#  235,
#  236,
#  237,
#  237,
#  237,
#  238,
#  238,
#  238,
#  239,
#  239,
#  240,
#  240,
#  240,
#  240,
#  240,
#  241,
#  241,
#  241,
#  241,
#  241,
#  241,
#  241,
#  241,
#  241,
#  241,
#  241,
#  241,
#  241,
#  241,
#  242,
#  242,
#  243,
#  243,
#  243,
#  243,
#  243,
#  244,
#  244,
#  244,
#  244,
#  244,
#  245,
#  245,
#  245,
#  245,
#  246,
#  246,
#  246,
#  246,
#  247,
#  247,
#  247,
#  247,
#  248,
#  248,
#  248,
#  249,
#  249,
#  249,
#  249,
#  249,
#  250,
#  250,
#  250,
#  250,
#  251,
#  251,
#  251,
#  251,
#  251,
#  251,
#  252,
#  252,
#  253,
#  253,
#  253,
#  253,
#  253,
#  254,
#  254,
#  255,
#  255,
#  255,
#  256,
#  256,
#  256,
#  256,
#  256,
#  257,
#  257,
#  257,
#  257,
#  257,
#  257,
#  258,
#  258,
#  258,
#  258,
#  258,
#  258,
#  258,
#  259,
#  259,
#  259,
#  259,
#  259,
#  259,
#  259,
#  259,
#  260,
#  260,
#  260,
#  260,
#  260,
#  260,
#  260,
#  260,
#  260,
#  260,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  262,
#  262,
#  262,
#  263,
#  263,
#  263,
#  264,
#  264,
#  264,
#  264,
#  264,
#  264,
#  264,
#  264,
#  265,
#  265,
#  265,
#  266,
#  266,
#  266,
#  266,
#  266,
#  266,
#  266,
#  266,
#  266,
#  266,
#  267,
#  267,
#  267,
#  267,
#  267,
#  268,
#  268,
#  268,
#  268,
#  269,
#  269,
#  269,
#  269,
#  269,
#  269,
#  269,
#  269,
#  270,
#  270,
#  270,
#  270,
#  270,
#  270,
#  270,
#  271,
#  271,
#  271,
#  271,
#  271,
#  271,
#  271,
#  271,
#  271,
#  272,
#  272,
#  272,
#  272,
#  272,
#  272,
#  272,
#  272,
#  272,
#  272,
#  273,
#  273,
#  273,
#  273,
#  273,
#  273,
#  273,
#  273,
#  274,
#  274,
#  274,
#  274,
#  275,
#  275,
#  275,
#  276,
#  276,
#  276,
#  276,
#  276,
#  276,
#  276,
#  276,
#  276,
#  277,
#  277,
#  277,
#  277,
#  277,
#  278,
#  278,
#  278,
#  278,
#  278,
#  278,
#  278,
#  278,
#  278,
#  278,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  280,
#  280,
#  280,
#  280,
#  280,
#  280,
#  280,
#  280,
#  280,
#  280,
#  280,
#  280,
#  281,
#  281,
#  281,
#  281,
#  281,
#  281,
#  281,
#  281,
#  281,
#  282,
#  282,
#  282,
#  282,
#  282,
#  282,
#  282,
#  283,
#  283,
#  283,
#  283,
#  283,
#  283,
#  283,
#  284,
#  284,
#  284,
#  284,
#  284,
#  284,
#  284,
#  284,
#  285,
#  285,
#  285,
#  285,
#  285,
#  285,
#  285,
#  286,
#  286,
#  286,
#  286,
#  286,
#  287,
#  287,
#  287,
#  287,
#  287,
#  287,
#  287,
#  287,
#  287,
#  288,
#  288,
#  288,
#  288,
#  288,
#  288,
#  288,
#  288,
#  288,
#  288,
#  289,
#  289,
#  289,
#  289,
#  289,
#  289,
#  289,
#  289,
#  289,
#  290,
#  290,
#  290,
#  290,
#  290,
#  290,
#  290,
#  290,
#  291,
#  291,
#  291,
#  291,
#  291,
#  291,
#  291,
#  292,
#  292,
#  292,
#  292,
#  292,
#  292,
#  292,
#  292,
#  292,
#  292,
#  292,
#  293,
#  293,
#  293,
#  293,
#  293,
#  293,
#  293,
#  293,
#  293,
#  293,
#  293,
#  293,
#  293,
#  293,
#  293,
#  294,
#  294,
#  294,
#  294,
#  294,
#  294,
#  294,
#  294,
#  294,
#  294,
#  294,
#  294,
#  294,
#  294,
#  294,
#  295,
#  295,
#  295,
#  295,
#  295,
#  295,
#  295,
#  295,
#  295,
#  296,
#  296,
#  296,
#  296,
#  296,
#  296,
#  296,
#  296,
#  297,
#  297,
#  297,
#  297,
#  297,
#  297,
#  297,
#  297,
#  297,
#  297,
#  297,
#  297,
#  297,
#  297,
#  298,
#  298,
#  298,
#  298,
#  298,
#  298,
#  298,
#  298,
#  298,
#  298,
#  298,
#  298,
#  298,
#  298,
#  298,
#  299,
#  299,
#  299,
#  299,
#  299,
#  299,
#  299,
#  299,
#  299,
#  299,
#  299,
#  299,
#  299,
#  299,
#  299,
#  299,
#  299,
#  299,
#  299,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  300,
#  301,
#  301,
#  301,
#  301,
#  301,
#  301,
#  301,
#  301,
#  301,
#  301,
#  301,
#  301,
#  301,
#  301,
#  301,
#  301,
#  301,
#  302,
#  302,
#  302,
#  302,
#  302,
#  302,
#  302,
#  302,
#  302,
#  302,
#  302,
#  302,
#  302,
#  302,
#  302,
#  303,
#  303,
#  303,
#  303,
#  303,
#  303,
#  303,
#  303,
#  303,
#  303,
#  303,
#  303,
#  303,
#  303,
#  303,
#  304,
#  304,
#  304,
#  304,
#  304,
#  304,
#  304,
#  304,
#  304,
#  304,
#  305,
#  305,
#  305,
#  305,
#  305,
#  305,
#  305,
#  305,
#  305,
#  305,
#  305,
#  305,
#  305,
#  305,
#  306,
#  306,
#  306,
#  306,
#  306,
#  306,
#  306,
#  306,
#  306,
#  306,
#  306,
#  306,
#  306,
#  306,
#  307,
#  307,
#  307,
#  307,
#  307,
#  307,
#  307,
#  307,
#  307,
#  307,
#  307,
#  307,
#  308,
#  308,
#  308,
#  308,
#  308,
#  308,
#  308,
#  308,
#  308,
#  308,
#  308,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  309,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  311,
#  311,
#  311,
#  311,
#  311,
#  311,
#  311,
#  311,
#  311,
#  311,
#  311,
#  311,
#  311,
#  311,
#  311,
#  311,
#  311,
#  311,
#  311,
#  311,
#  312,
#  312,
#  312,
#  312,
#  312,
#  312,
#  312,
#  312,
#  312,
#  312,
#  312,
#  312,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  313,
#  314,
#  314,
#  314,
#  314,
#  314,
#  314,
#  314,
#  314,
#  314,
#  314,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  316,
#  316,
#  316,
#  316,
#  316,
#  316,
#  316,
#  316,
#  316,
#  316,
#  316,
#  316,
#  316,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  318,
#  319,
#  319,
#  319,
#  319,
#  319,
#  319,
#  319,
#  319,
#  319,
#  319,
#  319,
#  319,
#  320,
#  320,
#  320,
#  320,
#  320,
#  320,
#  320,
#  320,
#  320,
#  320,
#  320,
#  320,
#  320,
#  320,
#  320,
#  320,
#  320,
#  320,
#  320,
#  321,
#  321,
#  321,
#  321,
#  321,
#  321,
#  321,
#  321,
#  321,
#  321,
#  321,
#  321,
#  321,
#  321,
#  321,
#  321,
#  321,
#  321,
#  321,
#  321,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  322,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  323,
#  324,
#  324,
#  324,
#  324,
#  324,
#  324,
#  324,
#  324,
#  324,
#  324,
#  324,
#  324,
#  325,
#  325,
#  325,
#  325,
#  325,
#  325,
#  325,
#  325,
#  325,
#  325,
#  325,
#  325,
#  325,
#  325,
#  326,
#  326,
#  326,
#  326,
#  326,
#  326,
#  326,
#  326,
#  326,
#  326,
#  326,
#  326,
#  326,
#  326,
#  326,
#  326,
#  326,
#  326,
#  326,
#  326,
#  326,
#  326,
#  327,
#  327,
#  ...]

# %%
string = ""
for curr_result in results:
    string += str(curr_result) + "\n"

# %%
with open('test_file.txt', 'w') as f:
    sys.stdout = f # Change the standard output to the file we created.
    print(string)
    sys.stdout = original_stdout # Reset the standard output to its original value
